# %%
# Dependencies
from bs4 import BeautifulSoup
from bs4.element import Comment
import requests
import csv
import re
from time import sleep
from random import randint
import json

# %%
#Build URL of the navigation pages - this page will contain hyperlinks to actual cases.
#e.g. if you put in 2016, it will have a page with SCC cases related to 2016. We will take those hyperlinks
#then later use those to scrape the actual cases
def buildurl(hyperlink):
    url = 'https://scc-csc.lexum.com'+str(hyperlink)+'?iframe=true'
    return url

def builduserurl(hyperlink):
    url_user = 'https://scc-csc.lexum.com'+str(hyperlink)
    return url_user

def print_to_txt(curr_case_code,soup_object):
    """Takes information and creates a file named e.g. 2019tcc203.txt with the case text inside"""

    filename = curr_case_code+".txt"
    filepath = "Data/tort_cases/"+str(filename)

    text_to_print=""
    
    print("curr_case_code: "+curr_case_code)
    with open (filepath,'a') as file_object:
        for item in soup_object.body.findAll("p"):
            item = item.text
            item = item.rstrip()
            try:
                file_object.write(str(item))
                file_object.write(" ")

            except:
                pass

# %%
cases_folder_name = "Data/"
cases_file_name = str("tort_cases_info.txt")

#load list of cases already scraped as case_dict_list
try:
    with open(str(cases_folder_name+cases_file_name)) as json_file:
            case_dict_list =  json.load(json_file)
except:
    case_dict_list=[]

len_cases_scraped = len(case_dict_list)

#load list of cases to scrape as criminal_hyperlinks
with open(str("tort_hyperlinks.txt")) as json_file:
    hyperlinkdict =  json.load(json_file)

hyperlinks = hyperlinkdict["hyperlinks_tort"]

for i in range(0,51):
    #make URL then get response
    ###~~~~~FUNNEL HYPERLINK LIST IN HERE
    hyperlink=hyperlinks[len_cases_scraped+i]
    url = buildurl(hyperlink)
    url_user = builduserurl(hyperlink)
    print(url_user)
    ###~~~~~

    response = requests.get(url)
    
    print(response.status_code)
    if response.status_code == 429:
        print("429 Error")
        break
    
    if response.status_code == 403:
        print("403 Error")
        break
    
    #make soup object
    soup_object = BeautifulSoup(response.text, 'html.parser')

    #collect table stats
    case_table = soup_object.body.find("table")
    table_rows = case_table.findAll("tr")
    info_sub_dict={}
    for row in table_rows:
        columns = row.findAll("td")
        row_data=[]
        keys=[]
        values=[]
        for column in columns:
            row_data.append(column.text)

        info_sub_dict.update({row_data[0]:row_data[1].strip()})

    #get case_code
    try:
        case_code_full=info_sub_dict["Neutral citation"]
        case_code_regex = re.search(r'(\d\d\d\d)(\s?)(\w\w\w)(\s?)(\d\d?\d?)',case_code_full)
        case_code = "tort"+str(case_code_regex[1])+case_code_regex[3]+str(case_code_regex[5])
    except:
        try:
            case_code = "tort"+info_sub_dict["Report"]
        except:
            try:
                case_code = "tort"+str(info_sub_dict["Recueil"])+" FRENCH"
            except:
                case_code="tort"+info_sub_dict["Case number"]
            
    
    info_sub_dict.update({"case_code":case_code})
        
    #get case_name
    case_name = soup_object.body.find("h3", class_="title").text
    info_sub_dict.update({"case_name":case_name})
        
    #build user url

    info_sub_dict.update({"url":url_user})
    info_sub_dict.update({"crim_tax":"tort"})

    #update info_dict_list
    case_dict_list.append(info_sub_dict)

    #print case contents to file
    print_to_txt(case_code,soup_object)

    print("~~")
    sleep(0.5)
    #print info_dict_list to file
    with open(str(cases_folder_name+cases_file_name), 'w') as outfile:
        json.dump(case_dict_list, outfile)
# Out:
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1929/index.do
# 200
# curr_case_code: tort2001SCC87
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1920/index.do
# 200
# curr_case_code: tort2001SCC79
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1921/index.do
# 200
# curr_case_code: tort2001SCC80
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1906/index.do
# 200
# curr_case_code: tort2001SCC66
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1898/index.do
# 200
# curr_case_code: tort2001SCC59
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1889/index.do
# 200
# curr_case_code: tort2001SCC50
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1876/index.do
# 200
# curr_case_code: tort2001SCC38
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1859/index.do
# 200
# curr_case_code: tort2001SCC23
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1825/index.do
# 200
# curr_case_code: tort2000SCC60
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1788/index.do
# 200
# curr_case_code: tort2000SCC26
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1786/index.do
# 200
# curr_case_code: tort2000SCC24
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1787/index.do
# 200
# curr_case_code: tort2000SCC25
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1773/index.do
# 200
# curr_case_code: tort2000SCC12
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1737/index.do
# 200
# curr_case_code: tort[1999] 3 SCR 408
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1716/index.do
# 200
# curr_case_code: tort[1999] 2 SCR 753
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1709/index.do
# 200
# curr_case_code: tort[1999] 2 SCR 534
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1710/index.do
# 200
# curr_case_code: tort[1999] 2 SCR 570
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1679/index.do
# 200
# curr_case_code: tort[1999] 1 SCR 201
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1637/index.do
# 200
# curr_case_code: tort[1998] 2 SCR 3
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1608/index.do
# 200
# curr_case_code: tort[1998] 1 SCR 591
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1605/index.do
# 200
# curr_case_code: tort[1998] 1 SCR 424
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1574/index.do
# 200
# curr_case_code: tort[1997] 3 SCR 1210
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1571/index.do
# 200
# curr_case_code: tort[1997] 3 SCR 1145
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1572/index.do
# 200
# curr_case_code: tort[1997] 3 SCR 1176
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1562/index.do
# 200
# curr_case_code: tort[1997] 3 SCR 925
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1527/index.do
# 200
# curr_case_code: tort[1997] 2 SCR 539
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1511/index.do
# 200
# curr_case_code: tort[1997] 2 SCR 165
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1444/index.do
# 200
# curr_case_code: tort[1996] 3 SCR 605
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1435/index.do
# 200
# curr_case_code: tort[1996] 3 SCR 458
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1424/index.do
# 200
# curr_case_code: tort[1996] 3 SCR 268
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1423/index.do
# 200
# curr_case_code: tort[1996] 3 SCR 211
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1416/index.do
# 200
# curr_case_code: tort[1996] 2 SCR 1071
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1328/index.do
# 200
# curr_case_code: tort[1995] 4 SCR 634
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1300/index.do
# 200
# curr_case_code: tort[1995] 3 SCR 674
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1286/index.do
# 200
# curr_case_code: tort[1995] 3 SCR 3
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1285/index.do
# 200
# curr_case_code: tort[1995] 2 SCR 1130
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1216/index.do
# 200
# curr_case_code: tort[1995] 1 SCR 131
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1215/index.do
# 200
# curr_case_code: tort[1995] 1 SCR 85
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1122/index.do
# 200
# curr_case_code: tort[1994] 1 SCR 670
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1115/index.do
# 200
# curr_case_code: tort[1994] 1 SCR 420
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1114/index.do
# 200
# curr_case_code: tort[1994] 1 SCR 359
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1116/index.do
# 200
# curr_case_code: tort[1994] 1 SCR 445
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1105/index.do
# 200
# curr_case_code: tort[1994] 1 SCR 157
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1099/index.do
# 200
# curr_case_code: tort[1994] 1 SCR 114
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1076/index.do
# 200
# curr_case_code: tort[1993] 4 SCR 279
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1070/index.do
# 200
# curr_case_code: tort[1993] 4 SCR 3
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1046/index.do
# 200
# curr_case_code: tort[1993] 3 SCR 206
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1045/index.do
# 200
# curr_case_code: tort[1993] 3 SCR 201
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/1000/index.do
# 200
# curr_case_code: tort[1993] 2 SCR 159
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/996/index.do
# 200
# curr_case_code: tort[1993] 2 SCR 119
# ~~
# https://scc-csc.lexum.com/scc-csc/scc-csc/en/item/948/index.do
# 200
# curr_case_code: tort[1993] 1 SCR 12
# ~~
